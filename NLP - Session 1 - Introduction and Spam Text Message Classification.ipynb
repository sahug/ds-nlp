# %% [markdown]
# # NLP - Session 1 - Introduction and Spam Text Message Classification

# %% [markdown]
# #### Objective
# Our objective of this code is to classify texts into two classes spam and ham.
#
# #### What is Natural Language Processing
# Natural Language Processing (NLP) is the field of Artificial Intelligence, where we analyse text using machine learning models
#
# #### Application of NLP
#  - Text Classification
#  - Spam Filters
#  - Voice text messaging
#  - Sentiment analysis
#  - Spell or grammar check
#  - Chat bot
#  - Search Suggestion
#  - Search Autocorrect
#  - Automatic Review Analysis system
#  - Machine translation
#  - And so much more
#  - Natural Language Understanding (Text classification)
#  - Natural Language Generation (Text Generation)
#
# #### The Process of Natural Language Understanding (Text Classification)
# ![image.png](attachment:image.png)
#
# #### Sentence Breakdown
# ![image-2.png](attachment:image-2.png)
#
# #### Natural Language Generation
# ![image-3.png](attachment:image-3.png)
#
# #### How to get started with NLP
# Following are the libraries which are generally used in Natural Language Processing.
#
#  - Sklearn
#  - Spacy
#  - NLTK
#  - Gensim
#  - Tensorflow and Keras
#
# `!pip install scikit-learn`
#
# `!python -m spacy download en`
#
# `!pip install -U spacy`
#
# `!pip install gensim`
#
# `!pip install lightgbm`
#
# ![image-4.png](attachment:image-4.png)
#
# #### Application of these libraries
#  - Tokenization
#  - Parts of Speech Tagging
#  - Entity Detection
#  - Dependency Parsing
#  - Noun Phrases
#  - Words-to-Vectors Integration
#  - Context Derivation
#  - and so much more
#
# #### Data Cleaning Options
#  - Case Normalization
#  - Removing Stop Words
#  - Removing Punctuations or Special Symbols
#  - Lemmatization and Stemming (word normalization)
#  - Parts of Speech Tagging
#  - Entity Detection
#  - Bag of Words
#  - Word-to-Vec
#
# #### Tokenization
# Tokenization is breaking the raw text into small chunks. Tokenization breaks the raw text into words, sentences called tokens. These tokens help in understanding the context or developing the model for the NLP. The tokenization helps in interpreting the meaning of the text by analyzing the sequence of the words.
#
# #### Parts of Speech Tagging
# A Part-Of-Speech Tagger (POS Tagger) is a piece of software that reads text in some language and assigns parts of speech to each word (and other token), such as noun, verb, adjective, etc., although generally computational applications use more fine-grained POS tags like ‘noun-plural.
#
# #### Entity Detection
# Named entity recognition (NER), also known as entity chunking/extraction , is a popular technique used in information extraction to identify and segment the named entities and classify or categorize them under various predefined classes.
#
# #### Dependency Parsing
# Syntactic Parsing or Dependency Parsing is the task of recognizing a sentence and assigning a syntactic structure to it. The most widely used syntactic structure is the parse tree which can be generated using some parsing algorithms. These parse trees are useful in various applications like grammar checking or more importantly it plays a critical role in the semantic analysis stage.
#
# #### Noun Phrases
# Noun phrases are part of speech patterns that include a noun. They can also include whatever other parts of speech make grammatical sense, and can include multiple nouns. Some common noun phrase patterns are:
#
# #### Noun
#  - Noun-Noun - Noun
#  - Adjective(s) - Noun
#  - Verb-(Adjectives-) - Noun
#
# #### Words-to-Vectors Integration
# Computers interact with humans in programming languages which are unambiguous, precise and often structured. However, natural (human) language has a lot of ambiguity. There are multiple words with same meaning (synonyms), words with multiple meanings (polysemy) some of which are entirely opposite in nature (auto-antonyms), and words which behave differently when used as noun and verb. These words make sense contextually in natural language which humans can comprehend and distinguish easily, but machines can’t. That’s what makes NLP one of the most difficult and interesting tasks in AI.
# Word2Vec is a group of models which helps derive relations between a word and its contextual words.
#
# #### Case Normalization
# Normalization is a process that converts a list of words to a more uniform sequence. For example, converting all words to lowercase will simplify the searching process.
#
# #### Removing Stop Words
# A stop word is a commonly used word (such as “the”, “a”, “an”, “in”) that a search engine has been programmed to ignore, both when indexing entries for searching and when retrieving them as the result of a search query.
# To check the list of stopwords you can type the following commands in the python shell.
#
# `import nltk`
#
# `from nltk.corpus import stopwords`
#
# `print(stopwords.words('english'))`
#
# #### Stemming
# Stemming is the process of reducing inflection in words to their root forms such as mapping a group of words to the same stem even if the stem itself is not a valid word in the Language.
#
#  - Playing -------> Play
#  - Plays ---------> Play
#  - Played --------> Play
#
# #### Lemmatisation
# Lemmatisation (or lemmatization) in linguistics is the process of grouping together the inflected forms of a word so they can be analysed as a single item, identified by the word’s lemma, or dictionary form.
# is,am, are ------> be
#
# ##### Example
#
# the boy's cars are different colors ------> the boy car be differ color
#
# #### What will be covered in this blog
#  - Introduction of NLP and Spam detection using sklearn
#  - Reading Text and PDF files in Python
#  - Tokenization
#  - Parts of Speech Tagging
#  - Word-to-Vectors
#  - Then real-world practical examples
#
# #### Bag of Words – The Simples Word Embedding Technique
# `doc1 = "I am high"`
#
# `doc2 = "Yes I am high"`
#
# `doc3 = "I am kidding"`
#
# ![image-5.png](attachment:image-5.png)
# By comparing the vectors we see that some words are common
#
# #### Bag of Words and Tf-idf (Term Frequency times Inverse Document Frequency)
# ![image-6.png](attachment:image-6.png)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data/nlp-spam.tsv", sep="\t")
df.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2

# %%
df.isnull().sum()
# Out:
# label      0
# message    0
# length     0
# punct      0
# dtype: int64

# %%
len(df)
# Out:
# 5572

# %%
df["label"].value_counts()
# Out:
# ham     4825
# spam     747
# Name: label, dtype: int64

# %% [markdown]
# As we can see our data is highly unbalanced. So we need to balance the data.
#
# Balancing the data so that we have equal number of spam and ham messages, so that our machine learning model learns well about both classes while training .

# %% [markdown]
# ### Balancing Data

# %%
ham = df[df["label"]=="ham"]
ham.head()
# Out:
#   label                                            message  length  punct
# 0   ham  Go until jurong point, crazy.. Available only ...     111      9
# 1   ham                      Ok lar... Joking wif u oni...      29      6
# 3   ham  U dun say so early hor... U c already then say...      49      6
# 4   ham  Nah I don't think he goes to usf, he lives aro...      61      2
# 6   ham  Even my brother is not like to speak with me. ...      77      2

# %%
spam = df[df["label"]=="spam"]
spam.head()
# Out:
#    label                                            message  length  punct
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...     155      6
# 5   spam  FreeMsg Hey there darling it's been 3 week's n...     147      8
# 8   spam  WINNER!! As a valued network customer you have...     157      6
# 9   spam  Had your mobile 11 months or more? U R entitle...     154      2
# 11  spam  SIX chances to win CASH! From 100 to 20,000 po...     136      8

# %%
ham.shape, spam.shape
# Out:
# ((4825, 4), (747, 4))

# %% [markdown]
# Ramdomly selecting same amount of sample from ham to balance the spam dataset.

# %%
ham = ham.sample(spam.shape[0])

# %%
ham.shape, spam.shape
# Out:
# ((747, 4), (747, 4))

# %% [markdown]
# As we can see above both ham and pam has same amount of data. Now lets combine both ham and spam dataset.

# %%
data = ham.append(spam, ignore_index=True)
data.tail()
# Out:
#      label                                            message  length  punct
# 1489  spam  Want explicit SEX in 30 secs? Ring 02073162414...      90      3
# 1490  spam  ASKED 3MOBILE IF 0870 CHATLINES INCLU IN FREE ...     158      5
# 1491  spam  Had your contract mobile 11 Mnths? Latest Moto...     160      8
# 1492  spam  REMINDER FROM O2: To get 2.50 pounds free call...     147      3
# 1493  spam  This is the 2nd time we have tried 2 contact u...     160      8

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# #### Exploring Length

# %%
plt.hist(data[data["label"]=="ham"]["length"], bins=100, alpha=0.7)
plt.hist(data[data["label"]=="spam"]["length"], bins=100, alpha=0.7)
plt.show()

# %% [markdown]
# #### Exploring Punctuation

# %%
plt.hist(data[data["label"]=="ham"]["punct"], bins=100, alpha=0.7)
plt.hist(data[data["label"]=="spam"]["punct"], bins=100, alpha=0.7)
plt.show()

# %% [markdown]
# ## Data Preperation

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.pipeline import Pipeline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
x = data["message"]
y = data["label"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=0, shuffle=True, stratify=y)

# %%
x_train.head
# Out:
# <bound method NDFrame.head of 1128    U’ve Bin Awarded £50 to Play 4 Instant Cash. C...
# 742         Also remember the beads don't come off. Ever.
# 477               Did he just say somebody is named tampa
# 542                      Then ü come n pick me at 530 ar?
# 1277    Ringtone Club: Gr8 new polys direct to your mo...
#                               ...
# 1211    Bloomberg -Message center +447797706009 Why wa...
# 312     Its a big difference.  &lt;#&gt;  versus  &lt;...
# 268                               I am sorry it hurt you.
# 272     Yar... I tot u knew dis would happen long ago ...
# 1222    Text BANNEDUK to 89555 to see! cost 150p texto...
# Name: message, Length: 1045, dtype: object>

# %% [markdown]
# ## Bag of Words Creation

# %%
vectorizer = TfidfVectorizer()

# %%
X_train_vect = vectorizer.fit_transform(x_train)

# %%
X_train_vect.shape
# Out:
# (1045, 3673)

# %% [markdown]
# ## Pipeline for Tf-idf and Random Forest Classifier

# %%
clf = Pipeline(
    [
        ("tfidf", TfidfVectorizer()), 
        ("clf", RandomForestClassifier(n_estimators=100, n_jobs=-1))
    ]
)

# %%
clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf', RandomForestClassifier(n_jobs=-1))])

# %%
y_pred = clf.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[223,   2],
#        [ 27, 197]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.89      0.99      0.94       225
#         spam       0.99      0.88      0.93       224
#
#     accuracy                           0.94       449
#    macro avg       0.94      0.94      0.94       449
# weighted avg       0.94      0.94      0.94       449

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9354120267260579

# %%
clf.predict(["Hi, this is me"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict([".....what's going on?????"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["Congrats! You have won free ticket to USA this summer. TEXT 'WON' to 123456"])
# Out:
# array(['spam'], dtype=object)

# %% [markdown]
# ## Pipeline for Tf-idf and SVM

# %%
clf = Pipeline(
    [
        ("tfidf", TfidfVectorizer()), 
        ("clf", SVC(C=1000, gamma="auto"))
    ]
)

# %%
clf.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('clf', SVC(C=1000, gamma='auto'))])

# %%
y_pred = clf.predict(x_test)

# %%
confusion_matrix(y_test, y_pred)
# Out:
# array([[220,   5],
#        [ 16, 208]])

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.93      0.98      0.95       225
#         spam       0.98      0.93      0.95       224
#
#     accuracy                           0.95       449
#    macro avg       0.95      0.95      0.95       449
# weighted avg       0.95      0.95      0.95       449

# %%
accuracy_score(y_test, y_pred)
# Out:
# 0.9532293986636972

# %%
clf.predict(["Hi, this is me"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict([".....what's going on?????"])
# Out:
# array(['ham'], dtype=object)

# %%
clf.predict(["Congrats! You have won free ticket to USA this summer. TEXT 'WON' to 123456"])
# Out:
# array(['spam'], dtype=object)

# %% [markdown]
# ## Word2Vec

# %% [markdown]
# - Now we convert text data to word embeddings using Word2vec, for that we import gensim library
# - To convert each message into vector form first we tokenize each message.
# - Now we convert each token i.e. each word into wordembedding using word2vec which we import using gensim.
# - After converting each word to vector (embedding) we take average of all word vectors to obtain vector for message . which is final feature vector for message

# %%
import gensim
import nltk

nltk.download('punkt')

from nltk.tokenize import word_tokenize

embedding_dim=100
text=data['message']

Text=[]
for i in range(data.shape[0]):
    text1=word_tokenize(text[i])
    Text=text1+Text



model= gensim.models.Word2Vec(sentences=[Text], size=embedding_dim, workers=4, min_count=1)
words=list(model.wv.vocab)

# print(text1)
# print(model[text1])
# vector=list(map(lambda x: sum(x)/len(x), zip(*model[text1])))
# print(vector)
def word_2_vec(x):
    t1=word_tokenize(x)
    model[t1]
    v=list(map(lambda y: sum(y)/len(y), zip(*model[t1])))
    a=np.array(v)
    return a.reshape(1,-1)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/gajendrasahu/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# Applying word2vec to each text message

# %%
data['vec'] = data['message'].apply(lambda x: word_2_vec(x))
data.head()
# Out:
# /Users/gajendrasahu/opt/anaconda3/envs/tensorflow20/lib/python3.7/site-packages/ipykernel_launcher.py:27: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /Users/gajendrasahu/opt/anaconda3/envs/tensorflow20/lib/python3.7/site-packages/ipykernel_launcher.py:28: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   label                                            message  length  punct  \
# 0   ham  Hello handsome ! Are you finding that job ? No...     152      7
# 1   ham                            So why didnt you holla?      23      1
# 2   ham                            That means get the door      23      0
# 3   ham  Just sent you an email – to an address with in...      72      2
# 4   ham  If anyone calls for a treadmill say you'll buy...     127     10
#
#                                                  vec
# 0  [[-0.014311159295947149, 0.02936451666579215, ...
# 1  [[-0.011495068727526814, 0.02616110220939542, ...
# 2  [[-0.01545796263962984, 0.024922946351580322, ...
# 3  [[-0.02099369783213155, 0.04070401954231784, 0...
# 4  [[-0.016476783119501574, 0.03781581545926576, ...

# %% [markdown]
# Here we are converting each feature vector pf a message in columns of dataframe

# %%
w_vec=np.concatenate(data['vec'].to_numpy(), axis=0)
w_vec.shape
# Out:
# (1494, 100)

# %%
word_vec=pd.DataFrame(w_vec)
word_vec.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.014311  0.029365  0.002830  0.012019  0.016493 -0.000253  0.008331
# 1 -0.011495  0.026161  0.003100  0.008763  0.013882  0.000237  0.006500
# 2 -0.015458  0.024923  0.002729  0.007348  0.014885  0.001872  0.009722
# 3 -0.020994  0.040704  0.004505  0.015594  0.021395 -0.000167  0.009868
# 4 -0.016477  0.037816  0.003920  0.014946  0.019981 -0.000097  0.008928
#
#          7         8         9   ...        90        91        92        93  \
# 0 -0.017598  0.020035 -0.012663  ...  0.007939  0.010199  0.002905 -0.004191
# 1 -0.013429  0.017226 -0.011442  ...  0.006886  0.010098  0.002825 -0.003698
# 2 -0.017231  0.020021 -0.013091  ...  0.006637  0.007341  0.000734 -0.002699
# 3 -0.023875  0.027298 -0.016167  ...  0.010060  0.013903  0.004558 -0.005479
# 4 -0.022586  0.025528 -0.015027  ...  0.008965  0.013539  0.003652 -0.005591
#
#          94        95        96        97        98        99
# 0 -0.006098 -0.028744  0.025928  0.002108  0.019109 -0.012492
# 1 -0.006337 -0.022426  0.022564  0.002685  0.016288 -0.012051
# 2 -0.006602 -0.027041  0.021867  0.002881  0.016724 -0.012105
# 3 -0.008446 -0.039800  0.035466  0.001366  0.026517 -0.018447
# 4 -0.009553 -0.036764  0.033081  0.002102  0.024997 -0.017570
#
# [5 rows x 100 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(word_vec, data['label'], test_size = 0.3, random_state=0, shuffle = True, stratify=data['label'])

# %% [markdown]
# ## SVM GridSearchCV
#
# - In machine learning, support-vector machines (SVMs, also support-vector networks) are supervised learning models with associated learning algorithms that analyze data used for classification and regression analysis.
# - In addition to performing linear classification, SVMs can efficiently perform a non-linear classification using what is called the kernel trick, implicitly mapping their inputs into high-dimensional feature spaces

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

Parameter_svc=[{'cache_size': [300,400,200],'tol': [0.0011,0.002,0.003],
                'kernel': ['rbf','poly'],
               'degree': [3,4,5]}]
scores = ['accuracy']

clf_svc = GridSearchCV(SVC(), Parameter_svc, scoring='accuracy', verbose=2, cv=5
                         )
clf_svc.fit(X_train, y_train)


print(clf_svc.best_params_)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.0011 ................
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.1s remaining:    0.0s
# [CV] . cache_size=300, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=300, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=300, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=300, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=300, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=300, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=400, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=400, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=400, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=400, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=400, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=3, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=3, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=3, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=3, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=3, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=4, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=4, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=4, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=4, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=4, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.0011 ................
# [CV] . cache_size=200, degree=5, kernel=rbf, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.002 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=rbf, tol=0.003 .................
# [CV] .. cache_size=200, degree=5, kernel=rbf, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.0011 ...............
# [CV]  cache_size=200, degree=5, kernel=poly, tol=0.0011, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.002 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.002, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.003, total=   0.1s
# [CV] cache_size=200, degree=5, kernel=poly, tol=0.003 ................
# [CV] . cache_size=200, degree=5, kernel=poly, tol=0.003, total=   0.1s
# {'cache_size': 300, 'degree': 3, 'kernel': 'rbf', 'tol': 0.003}
# [Parallel(n_jobs=1)]: Done 270 out of 270 | elapsed:   23.2s finished

# %%
y_pred_svm = clf_svc.predict(X_test)

# %%
accuracy_score(y_pred_svm, y_test)
# Out:
# 0.7193763919821826

# %%
print(classification_report(y_test, y_pred_svm))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.75      0.66      0.70       225
#         spam       0.70      0.78      0.73       224
#
#     accuracy                           0.72       449
#    macro avg       0.72      0.72      0.72       449
# weighted avg       0.72      0.72      0.72       449

# %% [markdown]
# ## LGBMclassifier
# - Light GBM is a gradient boosting framework that uses tree based learning algorithm.
# - Light GBM grows tree vertically while other algorithm grows trees horizontally meaning that Light GBM grows tree leaf-wise while other algorithm grows level-wise. It will choose the leaf with max delta loss to grow. When growing the same leaf, Leaf-wise algorithm can reduce more loss than a level-wise algorithm.

# %%
from lightgbm import LGBMClassifier
Parameter_lgbm=[{'num_leaves':[31,40,50],
              'max_depth':[3,4,5,6],
              'learning_rate':[0.1,0.05,0.2,0.15],
             'n_estimators':[700]}]
scores = ['accuracy']
clf_lgbm = GridSearchCV(LGBMClassifier(), Parameter_lgbm,
                    scoring='accuracy', verbose=2, cv=5)                         
clf_lgbm.fit(X_train,y_train)
print(clf_lgbm.best_params_)
# Out:
# Fitting 5 folds for each of 48 candidates, totalling 240 fits
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31 .
# /Users/gajendrasahu/opt/anaconda3/envs/tensorflow20/lib/python3.7/site-packages/lightgbm/__init__.py:48: UserWarning: Starting from version 2.2.1, the library file in distribution wheels for macOS is built by the Apple Clang (Xcode_8.3.3) compiler.
# This means that in case of installing LightGBM from PyPI via the ``pip install lightgbm`` command, you don't need to install the gcc compiler anymore.
# Instead of that, you need to install the OpenMP library, which is required for running LightGBM on the system with the Apple Clang compiler.
# You can install the OpenMP library by the following command: ``brew install libomp``.
#   "You can install the OpenMP library by the following command: ``brew install libomp``.", UserWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31, total=   1.6s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31 .
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=31, total=   2.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40, total=   2.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40, total=   3.2s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40, total=   2.2s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40, total=   1.3s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=40, total=   1.2s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50, total=   1.5s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50, total=   1.1s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31, total=   1.6s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=31, total=   2.2s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40, total=   2.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40, total=   2.3s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40, total=   3.6s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40, total=   1.6s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=40, total=   1.5s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50, total=   1.9s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50, total=   2.4s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50, total=   2.0s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50, total=   3.1s
# [CV] learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=4, n_estimators=700, num_leaves=50, total=   1.8s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31, total=   2.8s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31, total=   2.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31, total=   2.3s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=31, total=   2.2s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40, total=   2.2s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40, total=   1.9s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40, total=   2.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40, total=   2.0s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=40, total=   2.1s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50, total=   2.2s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50, total=   1.9s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50, total=   2.7s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50, total=   2.2s
# [CV] learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=5, n_estimators=700, num_leaves=50, total=   2.1s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31, total=   2.7s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31, total=   2.1s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31, total=   2.1s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=31, total=   2.2s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40, total=   2.6s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40, total=   2.0s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40, total=   2.5s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40, total=   3.3s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=40, total=   2.8s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50, total=   2.3s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50, total=   2.1s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50, total=   2.2s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50, total=   1.9s
# [CV] learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.1, max_depth=6, n_estimators=700, num_leaves=50, total=   2.1s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=31, total=   1.1s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40, total=   1.8s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=40, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50, total=   1.3s
# [CV] learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=3, n_estimators=700, num_leaves=50, total=   1.3s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31, total=   2.5s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31, total=   2.1s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=31, total=   1.8s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40, total=   2.0s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40, total=   1.8s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40, total=   2.4s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40, total=   2.7s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=40, total=   1.7s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50, total=   2.0s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50, total=   2.7s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50, total=   2.0s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50, total=   1.8s
# [CV] learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=4, n_estimators=700, num_leaves=50, total=   2.4s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31, total=   2.2s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31, total=   2.4s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40, total=   1.9s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40, total=   2.2s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40, total=   2.0s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40, total=   2.1s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=40, total=   2.7s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50, total=   2.2s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50, total=   2.4s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50, total=   2.2s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50, total=   2.2s
# [CV] learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=5, n_estimators=700, num_leaves=50, total=   2.8s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31, total=   2.8s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31, total=   2.5s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31, total=   2.9s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31, total=   2.7s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=31, total=   2.6s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40, total=   2.4s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40, total=   4.3s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40, total=   3.6s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40, total=   2.6s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=40, total=   3.9s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50, total=   2.5s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50, total=   2.8s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50, total=   3.0s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50, total=   2.7s
# [CV] learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.05, max_depth=6, n_estimators=700, num_leaves=50, total=   2.6s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40, total=   1.0s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40, total=   0.9s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40, total=   0.9s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=40, total=   1.4s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50, total=   1.4s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50, total=   1.1s
# [CV] learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=3, n_estimators=700, num_leaves=50, total=   2.0s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31, total=   2.8s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31, total=   2.6s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31, total=   1.4s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=31, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50, total=   1.1s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50, total=   1.4s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=4, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31, total=   1.8s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40, total=   1.3s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40, total=   1.8s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40, total=   2.1s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50, total=   1.6s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50, total=   1.1s
# [CV] learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=5, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=31, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40, total=   1.3s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=40, total=   1.3s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50, total=   1.6s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50 .
# [CV]  learning_rate=0.2, max_depth=6, n_estimators=700, num_leaves=50, total=   1.2s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31, total=   1.1s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=31, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40, total=   1.2s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40, total=   1.4s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=40, total=   1.1s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50, total=   1.1s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=3, n_estimators=700, num_leaves=50, total=   1.0s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31, total=   1.3s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31, total=   1.4s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31, total=   2.3s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=31, total=   2.0s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40, total=   2.2s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40, total=   1.9s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40, total=   1.3s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40, total=   1.3s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=40, total=   1.3s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50, total=   1.5s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50, total=   3.4s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50, total=   3.2s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50, total=   1.7s
# [CV] learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=4, n_estimators=700, num_leaves=50, total=   1.3s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31, total=   1.5s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31, total=   2.4s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31, total=   2.1s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31, total=   4.5s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=31, total=   9.9s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40, total=   8.5s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40, total=   2.3s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40, total=   1.9s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40, total=   2.5s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=40, total=   1.7s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50, total=   2.1s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50, total=   1.8s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50, total=   1.9s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50, total=   1.8s
# [CV] learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=5, n_estimators=700, num_leaves=50, total=   1.8s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31, total=   1.6s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31, total=   4.0s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31, total=   7.4s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31, total=   4.5s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=31, total=   5.6s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40, total=   2.6s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40, total=   2.4s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40, total=   2.7s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40, total=   2.0s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=40, total=   4.2s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50, total=   2.6s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50, total=   4.8s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50, total=   5.3s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50, total=   3.8s
# [CV] learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50
# [CV]  learning_rate=0.15, max_depth=6, n_estimators=700, num_leaves=50, total=   3.7s
# [Parallel(n_jobs=1)]: Done 240 out of 240 | elapsed:  7.9min finished
# {'learning_rate': 0.15, 'max_depth': 4, 'n_estimators': 700, 'num_leaves': 31}

# %%
y_pred_lgbm = clf_lgbm.predict(X_test)

# %%
accuracy_score(y_pred_lgbm, y_test)
# Out:
# 0.8285077951002228

# %%
print(classification_report(y_test, y_pred_lgbm))
# Out:
#               precision    recall  f1-score   support
#
#          ham       0.83      0.82      0.83       225
#         spam       0.82      0.83      0.83       224
#
#     accuracy                           0.83       449
#    macro avg       0.83      0.83      0.83       449
# weighted avg       0.83      0.83      0.83       449

# %% [markdown]
# ### Summary
# From above results we can conclude that TFidf performs better than word embeddings , since even without hyperparamter tuning all models performed well on test data with accuracy above 93% in all models
