# %% [markdown]
# <a href="https://colab.research.google.com/github/sahug/ds-nlp/blob/main/NLP%20-%20Session%2023%20-%20Data%20Preprocessing%20and%20Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **NLP - Session 23 - Data Preprocessing and Cleaning**

# %% [markdown]
# ## **Punctuation Removal**

# %%
import pandas as pd
sample_data = ["I like English.",
               "I speak English, French and Thai.",
               "I don't often go swimming; I prefer to play tennis.",
               "You have two choices: finish the work today or lose the contract.",
               "This is a rather out-of-date book.",
               "In each town—London, Paris and Rome—we stayed in youth hostels.",
               "Where is Shangri-La?",
               "Help! she cried. I can't swim!",
               "Please press your browser's Refresh/Reload button.",
               "C:\Files\jo.doc",
               "'I love you,' she said.",
               "This is John's car.",
               "Have you read Harry Potter?",
               "b_l@cia.gov",
               "I went to Bangkok (my favourite city) and stayed there for two weeks.",
               "The newspaper reported that the hostages [most of them French] had been released.",
               'One happy customer wrote: "This is the best program...that I have ever seen."'
               ]
sample_df = pd.DataFrame(sample_data, columns=["original"])

# %%
import string
def preprocess_punctuation(text: str) -> str:
  return "".join([i for i in text if i not in string.punctuation])  
sample_df['processed'] = sample_df['original'].apply(lambda x:preprocess_punctuation(x))  
sample_df
# Out:
#                                              original  \
# 0                                     I like English.
# 1                   I speak English, French and Thai.
# 2   I don't often go swimming; I prefer to play te...
# 3   You have two choices: finish the work today or...
# 4                  This is a rather out-of-date book.
# 5   In each town—London, Paris and Rome—we stayed ...
# 6                                Where is Shangri-La?
# 7                      Help! she cried. I can't swim!
# 8   Please press your browser's Refresh/Reload but...
# 9                                     C:\Files\jo.doc
# 10                            'I love you,' she said.
# 11                                This is John's car.
# 12                        Have you read Harry Potter?
# 13                                        b_l@cia.gov
# 14  I went to Bangkok (my favourite city) and stay...
# 15  The newspaper reported that the hostages [most...
# 16  One happy customer wrote: "This is the best pr...
#
#                                             processed
# 0                                      I like English
# 1                     I speak English French and Thai
# 2    I dont often go swimming I prefer to play tennis
# 3   You have two choices finish the work today or ...
# 4                     This is a rather outofdate book
# 5   In each town—London Paris and Rome—we stayed i...
# 6                                  Where is ShangriLa
# 7                          Help she cried I cant swim
# 8     Please press your browsers RefreshReload button
# 9                                         CFilesjodoc
# 10                                I love you she said
# 11                                  This is Johns car
# 12                         Have you read Harry Potter
# 13                                           blciagov
# 14  I went to Bangkok my favourite city and stayed...
# 15  The newspaper reported that the hostages most ...
# 16  One happy customer wrote This is the best prog...

# %% [markdown]
# ## **Tokenization**

# %%
from nltk.tokenize import RegexpTokenizer
def tokenization(text):
  return RegexpTokenizer("\w+").tokenize(text)
sample_df['processed'] = sample_df['original'].apply(lambda x:tokenization(x))  
sample_df
# Out:
#                                              original  \
# 0                                     I like English.
# 1                   I speak English, French and Thai.
# 2   I don't often go swimming; I prefer to play te...
# 3   You have two choices: finish the work today or...
# 4                  This is a rather out-of-date book.
# 5   In each town—London, Paris and Rome—we stayed ...
# 6                                Where is Shangri-La?
# 7                      Help! she cried. I can't swim!
# 8   Please press your browser's Refresh/Reload but...
# 9                                     C:\Files\jo.doc
# 10                            'I love you,' she said.
# 11                                This is John's car.
# 12                        Have you read Harry Potter?
# 13                                        b_l@cia.gov
# 14  I went to Bangkok (my favourite city) and stay...
# 15  The newspaper reported that the hostages [most...
# 16  One happy customer wrote: "This is the best pr...
#
#                                             processed
# 0                                  [I, like, English]
# 1              [I, speak, English, French, and, Thai]
# 2   [I, don, t, often, go, swimming, I, prefer, to...
# 3   [You, have, two, choices, finish, the, work, t...
# 4          [This, is, a, rather, out, of, date, book]
# 5   [In, each, town, London, Paris, and, Rome, we,...
# 6                            [Where, is, Shangri, La]
# 7                 [Help, she, cried, I, can, t, swim]
# 8   [Please, press, your, browser, s, Refresh, Rel...
# 9                                 [C, Files, jo, doc]
# 10                          [I, love, you, she, said]
# 11                           [This, is, John, s, car]
# 12                   [Have, you, read, Harry, Potter]
# 13                                    [b_l, cia, gov]
# 14  [I, went, to, Bangkok, my, favourite, city, an...
# 15  [The, newspaper, reported, that, the, hostages...
# 16  [One, happy, customer, wrote, This, is, the, b...

# %% [markdown]
# ## **Stop Words**

# %%
import nltk
nltk.download('stopwords')
stopwords = nltk.corpus.stopwords.words("english")

def remove_stop_words(text):
  output =  [i for i in text if i not in stopwords]
  return output
sample_df['stopwords'] = sample_df['processed'].apply(lambda x:remove_stop_words(x))  
sample_df
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                                              original  \
# 0                                     I like English.
# 1                   I speak English, French and Thai.
# 2   I don't often go swimming; I prefer to play te...
# 3   You have two choices: finish the work today or...
# 4                  This is a rather out-of-date book.
# 5   In each town—London, Paris and Rome—we stayed ...
# 6                                Where is Shangri-La?
# 7                      Help! she cried. I can't swim!
# 8   Please press your browser's Refresh/Reload but...
# 9                                     C:\Files\jo.doc
# 10                            'I love you,' she said.
# 11                                This is John's car.
# 12                        Have you read Harry Potter?
# 13                                        b_l@cia.gov
# 14  I went to Bangkok (my favourite city) and stay...
# 15  The newspaper reported that the hostages [most...
# 16  One happy customer wrote: "This is the best pr...
#
#                                             processed  \
# 0                                  [I, like, English]
# 1              [I, speak, English, French, and, Thai]
# 2   [I, don, t, often, go, swimming, I, prefer, to...
# 3   [You, have, two, choices, finish, the, work, t...
# 4          [This, is, a, rather, out, of, date, book]
# 5   [In, each, town, London, Paris, and, Rome, we,...
# 6                            [Where, is, Shangri, La]
# 7                 [Help, she, cried, I, can, t, swim]
# 8   [Please, press, your, browser, s, Refresh, Rel...
# 9                                 [C, Files, jo, doc]
# 10                          [I, love, you, she, said]
# 11                           [This, is, John, s, car]
# 12                   [Have, you, read, Harry, Potter]
# 13                                    [b_l, cia, gov]
# 14  [I, went, to, Bangkok, my, favourite, city, an...
# 15  [The, newspaper, reported, that, the, hostages...
# 16  [One, happy, customer, wrote, This, is, the, b...
#
#                                             stopwords
# 0                                  [I, like, English]
# 1                   [I, speak, English, French, Thai]
# 2   [I, often, go, swimming, I, prefer, play, tennis]
# 3   [You, two, choices, finish, work, today, lose,...
# 4                          [This, rather, date, book]
# 5   [In, town, London, Paris, Rome, stayed, youth,...
# 6                                [Where, Shangri, La]
# 7                              [Help, cried, I, swim]
# 8   [Please, press, browser, Refresh, Reload, button]
# 9                                 [C, Files, jo, doc]
# 10                                    [I, love, said]
# 11                                  [This, John, car]
# 12                        [Have, read, Harry, Potter]
# 13                                    [b_l, cia, gov]
# 14  [I, went, Bangkok, favourite, city, stayed, tw...
# 15  [The, newspaper, reported, hostages, French, r...
# 16  [One, happy, customer, wrote, This, best, prog...

# %%
sample_df = sample_df.drop("stopwords", axis=1)

# %% [markdown]
# ## **Stemming**

# %%
from nltk.stem import PorterStemmer
def stemming(text):
  return [PorterStemmer().stem(i) for i in text]

sample_df['stemmed'] = sample_df['processed'].apply(lambda x:stemming(x))  
sample_df
# Out:
#                                              original  \
# 0                                     I like English.
# 1                   I speak English, French and Thai.
# 2   I don't often go swimming; I prefer to play te...
# 3   You have two choices: finish the work today or...
# 4                  This is a rather out-of-date book.
# 5   In each town—London, Paris and Rome—we stayed ...
# 6                                Where is Shangri-La?
# 7                      Help! she cried. I can't swim!
# 8   Please press your browser's Refresh/Reload but...
# 9                                     C:\Files\jo.doc
# 10                            'I love you,' she said.
# 11                                This is John's car.
# 12                        Have you read Harry Potter?
# 13                                        b_l@cia.gov
# 14  I went to Bangkok (my favourite city) and stay...
# 15  The newspaper reported that the hostages [most...
# 16  One happy customer wrote: "This is the best pr...
#
#                                             processed  \
# 0                                  [I, like, English]
# 1              [I, speak, English, French, and, Thai]
# 2   [I, don, t, often, go, swimming, I, prefer, to...
# 3   [You, have, two, choices, finish, the, work, t...
# 4          [This, is, a, rather, out, of, date, book]
# 5   [In, each, town, London, Paris, and, Rome, we,...
# 6                            [Where, is, Shangri, La]
# 7                 [Help, she, cried, I, can, t, swim]
# 8   [Please, press, your, browser, s, Refresh, Rel...
# 9                                 [C, Files, jo, doc]
# 10                          [I, love, you, she, said]
# 11                           [This, is, John, s, car]
# 12                   [Have, you, read, Harry, Potter]
# 13                                    [b_l, cia, gov]
# 14  [I, went, to, Bangkok, my, favourite, city, an...
# 15  [The, newspaper, reported, that, the, hostages...
# 16  [One, happy, customer, wrote, This, is, the, b...
#
#                                               stemmed
# 0                                  [i, like, english]
# 1              [i, speak, english, french, and, thai]
# 2   [i, don, t, often, go, swim, i, prefer, to, pl...
# 3   [you, have, two, choic, finish, the, work, tod...
# 4           [thi, is, a, rather, out, of, date, book]
# 5   [in, each, town, london, pari, and, rome, we, ...
# 6                            [where, is, shangri, la]
# 7                   [help, she, cri, i, can, t, swim]
# 8   [pleas, press, your, browser, s, refresh, relo...
# 9                                  [c, file, jo, doc]
# 10                          [i, love, you, she, said]
# 11                            [thi, is, john, s, car]
# 12                   [have, you, read, harri, potter]
# 13                                    [b_l, cia, gov]
# 14  [i, went, to, bangkok, my, favourit, citi, and...
# 15  [the, newspap, report, that, the, hostag, most...
# 16  [one, happi, custom, wrote, thi, is, the, best...

# %%
sample_df = sample_df.drop("stemmed", axis=1)

# %% [markdown]
# ## **Lemmatization**

# %%
from nltk.stem import WordNetLemmatizer
nltk.download('wordnet')
nltk.download('omw-1.4')

def lemmatize(text):
  return [WordNetLemmatizer().lemmatize(i) for i in text]

sample_df['lemma'] = sample_df['processed'].apply(lambda x:lemmatize(x))  
sample_df
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
#                                              original  \
# 0                                     I like English.
# 1                   I speak English, French and Thai.
# 2   I don't often go swimming; I prefer to play te...
# 3   You have two choices: finish the work today or...
# 4                  This is a rather out-of-date book.
# 5   In each town—London, Paris and Rome—we stayed ...
# 6                                Where is Shangri-La?
# 7                      Help! she cried. I can't swim!
# 8   Please press your browser's Refresh/Reload but...
# 9                                     C:\Files\jo.doc
# 10                            'I love you,' she said.
# 11                                This is John's car.
# 12                        Have you read Harry Potter?
# 13                                        b_l@cia.gov
# 14  I went to Bangkok (my favourite city) and stay...
# 15  The newspaper reported that the hostages [most...
# 16  One happy customer wrote: "This is the best pr...
#
#                                             processed  \
# 0                                  [I, like, English]
# 1              [I, speak, English, French, and, Thai]
# 2   [I, don, t, often, go, swimming, I, prefer, to...
# 3   [You, have, two, choices, finish, the, work, t...
# 4          [This, is, a, rather, out, of, date, book]
# 5   [In, each, town, London, Paris, and, Rome, we,...
# 6                            [Where, is, Shangri, La]
# 7                 [Help, she, cried, I, can, t, swim]
# 8   [Please, press, your, browser, s, Refresh, Rel...
# 9                                 [C, Files, jo, doc]
# 10                          [I, love, you, she, said]
# 11                           [This, is, John, s, car]
# 12                   [Have, you, read, Harry, Potter]
# 13                                    [b_l, cia, gov]
# 14  [I, went, to, Bangkok, my, favourite, city, an...
# 15  [The, newspaper, reported, that, the, hostages...
# 16  [One, happy, customer, wrote, This, is, the, b...
#
#                                                 lemma
# 0                                  [I, like, English]
# 1              [I, speak, English, French, and, Thai]
# 2   [I, don, t, often, go, swimming, I, prefer, to...
# 3   [You, have, two, choice, finish, the, work, to...
# 4          [This, is, a, rather, out, of, date, book]
# 5   [In, each, town, London, Paris, and, Rome, we,...
# 6                            [Where, is, Shangri, La]
# 7                 [Help, she, cried, I, can, t, swim]
# 8   [Please, press, your, browser, s, Refresh, Rel...
# 9                                 [C, Files, jo, doc]
# 10                          [I, love, you, she, said]
# 11                           [This, is, John, s, car]
# 12                   [Have, you, read, Harry, Potter]
# 13                                    [b_l, cia, gov]
# 14  [I, went, to, Bangkok, my, favourite, city, an...
# 15  [The, newspaper, reported, that, the, hostage,...
# 16  [One, happy, customer, wrote, This, is, the, b...
